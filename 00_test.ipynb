# %%
name=input("Enter your name: ")
print("Hello, " + name + "! Welcome to the program.")
# Out:
# Hello, mudit patil ! Welcome to the program.

# %%
print('mudit patil')
# Out:
# mudit patil

# %%
#create a simple if elif else code to check marks and give grade A,B,C,D
marks = int(input("Enter your marks: "))

if marks >= 80:
    grade = "A"
elif marks >= 60:
    grade = "B"
elif marks >= 40:
    grade = "C"
else:
    grade = "D"

print("Your grade is:", grade)
# Out:
# Your grade is: B
